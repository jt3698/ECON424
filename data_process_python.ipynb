# %%
import pandas as pd

movies = pd.read_csv(r'movies.csv')

# %%
movies.head()
# Out:
#        id                           title                            genres  \
# 0   76600        Avatar: The Way of Water  Science Fiction-Adventure-Action
# 1  631842              Knock at the Cabin           Horror-Mystery-Thriller
# 2  646389                           Plane         Action-Adventure-Thriller
# 3  505642  Black Panther: Wakanda Forever  Action-Adventure-Science Fiction
# 4  956101               The Eighth Clause                          Thriller
#
#   original_language                                           overview  \
# 0                en  Set more than a decade after the events of the...
# 1                en  While vacationing at a remote cabin a young gi...
# 2                en  After a heroic job of successfully landing his...
# 3                en  Queen Ramonda Shuri M’Baku Okoye and the Dora ...
# 4                la  Kat and Borja appear to be a perfect couple bu...
#
#    popularity                               production_companies release_date  \
# ...

# %%
movies_with_revenue = movies[movies.revenue > 0]
movies_with_revenue.head()
# Out:
#        id                           title                             genres  \
# 0   76600        Avatar: The Way of Water   Science Fiction-Adventure-Action
# 1  631842              Knock at the Cabin            Horror-Mystery-Thriller
# 2  646389                           Plane          Action-Adventure-Thriller
# 3  505642  Black Panther: Wakanda Forever   Action-Adventure-Science Fiction
# 6  315162    Puss in Boots: The Last Wish  Animation-Adventure-Comedy-Family
#
#   original_language                                           overview  \
# 0                en  Set more than a decade after the events of the...
# 1                en  While vacationing at a remote cabin a young gi...
# 2                en  After a heroic job of successfully landing his...
# 3                en  Queen Ramonda Shuri M’Baku Okoye and the Dora ...
# 6                en  Puss in Boots discovers that his passion for a...
#
# ...

# %%
movies_with_revenue.to_csv('movies_with_revenue.csv', index=False)
